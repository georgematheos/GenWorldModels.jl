# %%
using WAV;
using Gen;
import Random
include("model.jl")
include("plotting.jl")
include("proposals.jl")
include("gammatonegram.jl")
include("time_helpers.jl")

# %% [markdown]
# # Checking involutions

# %%
duration = 0.81
max_tones = 5
audio_sr = 20000
tstep = 0.010
mindur = 0.020
wts, f = gtg_weights(audio_sr);

# %% [markdown]
# ### Switch

# %%
constraints = choicemap()

constraints[:n_sources] = 6

constraints[:source => 1 => :n_tones] = 1
mu_erb_1 = 12; mu_amp_1 =0.9;
constraints[:source => 1 => :mu_erb] = mu_erb_1
constraints[:source => 1 => :mu_amp] = mu_amp_1
wait_1 = 0.101; dur_minus_min_1 = 0.080
constraints[:source => 1 => (:tone, 1) => :wait] = wait_1
constraints[:source => 1 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
constraints[:source => 1 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 1 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

constraints[:source => 2 => :n_tones] = 1
mu_erb_1 = 12; mu_amp_1 =0.9;
constraints[:source => 2 => :mu_erb] = mu_erb_1
constraints[:source => 2 => :mu_amp] = mu_amp_1
wait_1 = 0.2101; dur_minus_min_1 = 0.080
constraints[:source => 2 => (:tone, 1) => :wait] = wait_1
constraints[:source => 2 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
constraints[:source => 2 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 2 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

constraints[:source => 3 => :n_tones] = 1
mu_erb_1 = 12; mu_amp_1 =0.9;
constraints[:source => 3 => :mu_erb] = mu_erb_1
constraints[:source => 3 => :mu_amp] = mu_amp_1
wait_1 = 0.3201; dur_minus_min_1 = 0.080
constraints[:source => 3 => (:tone, 1) => :wait] = wait_1
constraints[:source => 3 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
constraints[:source => 3 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 3 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

constraints[:source => 4 => :n_tones] = 1
mu_erb_1 = 20; mu_amp_1 =0.9;
constraints[:source => 4 => :mu_erb] = mu_erb_1
constraints[:source => 4 => :mu_amp] = mu_amp_1
wait_1 = 0.4301; dur_minus_min_1 = 0.080
constraints[:source => 4 => (:tone, 1) => :wait] = wait_1
constraints[:source => 4 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
constraints[:source => 4 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 4 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

constraints[:source => 5 => :n_tones] = 1
mu_erb_1 = 20; mu_amp_1 =0.9;
constraints[:source => 5 => :mu_erb] = mu_erb_1
constraints[:source => 5 => :mu_amp] = mu_amp_1
wait_1 = 0.5401; dur_minus_min_1 = 0.080
constraints[:source => 5 => (:tone, 1) => :wait] = wait_1
constraints[:source => 5 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
constraints[:source => 5 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 5 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

constraints[:source => 6 => :n_tones] = 1
mu_erb_1 = 20; mu_amp_1 =0.9;
constraints[:source => 6 => :mu_erb] = mu_erb_1
constraints[:source => 6 => :mu_amp] = mu_amp_1
wait_1 = 0.6501; dur_minus_min_1 = 0.080
constraints[:source => 6 => (:tone, 1) => :wait] = wait_1
constraints[:source => 6 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
constraints[:source => 6 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 6 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

# constraints[:n_sources] = 2
# constraints[:source => 1 => :n_tones] = 1
# mu_erb_1 = 13; mu_amp_1 =0.9;
# constraints[:source => 1 => :mu_erb] = mu_erb_1
# constraints[:source => 1 => :mu_amp] = mu_amp_1
# wait_1 = 0.4; dur_minus_min_1 = 0.080
# constraints[:source => 1 => (:tone, 1) => :wait] = wait_1
# constraints[:source => 1 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
# t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
# constraints[:source => 1 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
# constraints[:source => 1 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

# constraints[:source => 2 => :n_tones] = 1
# mu_erb_2 =17; mu_amp_2 =0.9;
# constraints[:source => 2 => :mu_erb] = mu_erb_2
# constraints[:source => 2 => :mu_amp] = mu_amp_2 
# wait_2 = 0.6; dur_minus_min_2 = 0.080
# constraints[:source => 2 => (:tone, 1) => :wait]= wait_2
# constraints[:source => 2 => (:tone, 1) => :dur_minus_min]= dur_minus_min_2
# t = get_tone_sample_times([wait_2, wait_2+dur_minus_min_2 + 0.020], tstep)
# constraints[:source => 2 => (:tone, 1) => :erb]= fill(mu_erb_2, length(t))
# constraints[:source => 2 => (:tone, 1) => :amp]= fill(mu_amp_2, length(t));

# %%
tr, _ = generate(generate_scene, (max_tones, duration, wts, mindur, tstep, audio_sr), constraints)
scene_gram, t, scene_wave = get_retval(tr)
plot_gtg(tr[:scene], t, f, duration, audio_sr/2)

# %%
plot_sources(tr, scene_gram, 1)

# %%
(fwd_choices, fwd_score, fwd_ret) = propose(switch_randomness, (tr,))
(new_trace, bwd_choices, weight) = switch_involution(tr, fwd_choices, fwd_ret, ())
(bwd_score, _) = assess(switch_randomness, (new_trace,), bwd_choices)
println((weight - fwd_score + bwd_score))
println("Weight: $(weight), Fwd: $(fwd_score), Bwd: $(bwd_score)")
# trace, accepted = mh(trace, switch_randomness, (), switch_involution) 
plot_sources(new_trace, scene_gram, 1)
println(fwd_choices)
println("Backward choices")
println(bwd_choices)

# %%
println(get_choices(tr))
total = 0
for i = 1:new_trace[:n_sources]
single = project(new_trace, select(:source => i))
total += single
println("Source $i: $single")
end
println("Total: $total")
new_likelihood=logpdf(noisy_matrix,get_retval(new_trace)[1],scene_gram,0.1)
println("LIkelihood: $new_likelihood" )

println(project(new_trace,select(:n_sources)))
println(project(new_trace,select(:noise)))

# %%
tr, _ = generate(generate_scene, (max_tones, duration, wts, mindur, tstep, audio_sr), constraints)
scene_gram, t, scene_wave = get_retval(tr)
plot_gtg(tr[:scene], t, f, duration, audio_sr/2) 

(fwd_choices, fwd_score, fwd_ret) = propose(switch_randomness, (tr,))
(new_trace, bwd_choices, weight) = switch_involution(tr, fwd_choices, fwd_ret, ())
(bwd_score, _) = assess(switch_randomness, (new_trace,), bwd_choices)
println((weight - fwd_score + bwd_score))
println("Weight: $(weight), Fwd: $(fwd_score), Bwd: $(bwd_score)")
# trace, accepted = mh(trace, switch_randomness, (), switch_involution) 
plot_sources(new_trace, scene_gram, 1)
println(fwd_choices)
println("Backward choices")
println(bwd_choices)

# %%
observed_scene = scene_gram;

# %%
constraints = choicemap()

constraints[:n_sources] = 6
constraints[:noise] = 2.0
constraints[:scene] = observed_scene

constraints[:source => 1 => :n_tones] = 1
mu_erb_1 = 8; mu_amp_1 =0.9;
constraints[:source => 1 => :mu_erb] = mu_erb_1
constraints[:source => 1 => :mu_amp] = mu_amp_1
wait_1 = 0.101; dur_minus_min_1 = 0.080
constraints[:source => 1 => (:tone, 1) => :wait] = wait_1
constraints[:source => 1 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
constraints[:source => 1 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 1 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

constraints[:source => 2 => :n_tones] = 1
mu_erb_1 = 7; mu_amp_1 =0.9;
constraints[:source => 2 => :mu_erb] = mu_erb_1
constraints[:source => 2 => :mu_amp] = mu_amp_1
wait_1 = 0.2101; dur_minus_min_1 = 0.080
constraints[:source => 2 => (:tone, 1) => :wait] = wait_1
constraints[:source => 2 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
constraints[:source => 2 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 2 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

constraints[:source => 3 => :n_tones] = 1
mu_erb_1 = 9; mu_amp_1 =0.9;
constraints[:source => 3 => :mu_erb] = mu_erb_1
constraints[:source => 3 => :mu_amp] = mu_amp_1
wait_1 = 0.3201; dur_minus_min_1 = 0.080
constraints[:source => 3 => (:tone, 1) => :wait] = wait_1
constraints[:source => 3 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
constraints[:source => 3 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 3 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

constraints[:source => 4 => :n_tones] = 1
mu_erb_1 = 21; mu_amp_1 =0.9;
constraints[:source => 4 => :mu_erb] = mu_erb_1
constraints[:source => 4 => :mu_amp] = mu_amp_1
wait_1 = 0.4301; dur_minus_min_1 = 0.080
constraints[:source => 4 => (:tone, 1) => :wait] = wait_1
constraints[:source => 4 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
constraints[:source => 4 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 4 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

constraints[:source => 5 => :n_tones] = 1
mu_erb_1 = 22; mu_amp_1 =0.9;
constraints[:source => 5 => :mu_erb] = mu_erb_1
constraints[:source => 5 => :mu_amp] = mu_amp_1
wait_1 = 0.5401; dur_minus_min_1 = 0.080
constraints[:source => 5 => (:tone, 1) => :wait] = wait_1
constraints[:source => 5 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
constraints[:source => 5 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 5 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

constraints[:source => 6 => :n_tones] = 1
mu_erb_1 = 19; mu_amp_1 =0.9;
constraints[:source => 6 => :mu_erb] = mu_erb_1
constraints[:source => 6 => :mu_amp] = mu_amp_1
wait_1 = 0.6501; dur_minus_min_1 = 0.080
constraints[:source => 6 => (:tone, 1) => :wait] = wait_1
constraints[:source => 6 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
constraints[:source => 6 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 6 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

tr, _ = generate(generate_scene, (max_tones, duration, wts, mindur, tstep, audio_sr), constraints)
scene_gram, t, scene_wave = get_retval(tr)
plot_gtg(scene_gram, t, f, duration, audio_sr/2)

trace_list=[]
for idx = 1:400
# (fwd_choices, fwd_score, fwd_ret) = propose(switch_randomness, (tr,))
# (new_trace, bwd_choices, weight) = switch_involution(tr, fwd_choices, fwd_ret, ())
# (bwd_score, _) = assess(switch_randomness, (new_trace,), bwd_choices)
# println((weight - fwd_score + bwd_score))
# println("Weight: $(weight), Fwd: $(fwd_score), Bwd: $(bwd_score)")
new_trace, accepted = mh(tr, switch_randomness, (), switch_involution) 
@assert new_trace[:scene] == tr[:scene]
# @assert get_retval(new_trace)[1] == get_retval(tr)[1]
@assert new_trace[:noise] == tr[:noise]
# plot_sources(new_trace, scene_gram, idx)
println("ITERATION $idx: ", new_trace[:noise])
for source_idx  = 1:new_trace[:n_sources]
        println("source $source_idx: ", new_trace[:source => source_idx => :mu_erb])
    end
# println(fwd_choices)
# println("Backward choices")
# println(bwd_choices)
tr = new_trace
push!(trace_list,tr)
end
plot_sources(trace_list[end], scene_gram, 200)

# %%
plot_gtg(tr[:scene], t, f, duration, audio_sr/2)

# %%
tr=trace_list[end]
(fwd_choices, fwd_score, fwd_ret) = propose(switch_randomness, (tr,))
(new_trace, bwd_choices, weight) = switch_involution(tr, fwd_choices, fwd_ret, ())
(bwd_score, _) = assess(switch_randomness, (new_trace,), bwd_choices)
println((weight - fwd_score + bwd_score))
println("Weight: $(weight), Fwd: $(fwd_score), Bwd: $(bwd_score)")
# trace, accepted = mh(trace, switch_randomness, (), switch_involution) 
plot_sources(new_trace, scene_gram, 1)
println(fwd_choices)
println("Backward choices")
println(bwd_choices)

# %%
println("We think this is bad")
total = 0
for i = 1:tr[:n_sources]
single = project(tr, select(:source => i))
total += single
println("Source $i: $single")
end
println("Total: $total")
new_likelihood=logpdf(noisy_matrix,get_retval(tr)[1],scene_gram,tr[:noise])
println("LIkelihood: $new_likelihood" )

println(project(tr,select(:n_sources)))
println(project(tr,select(:noise)))


println("We think this is good")
total = 0
for i = 1:new_trace[:n_sources]
single = project(new_trace, select(:source => i))
total += single
println("Source $i: $single")
end
println("Total: $total")
new_likelihood=logpdf(noisy_matrix,get_retval(new_trace)[1],scene_gram,new_trace[:noise])
println("LIkelihood: $new_likelihood" )

println(project(new_trace,select(:n_sources)))
println(project(new_trace,select(:noise)))

println(project(tr,select(:noise)))
println(project(new_trace,select(:noise)))

# %%
tr[:noise] == new_trace[:noise]

# %%
tr[:scene] == new_trace[:scene]

# %%
maximum(abs.(get_retval(tr)[1] .- get_retval(new_trace)[1]))
xs = [string(round(i,digits=2)) for i = t]
ys = [string(round(i,digits=1)) for i = f]
imshow(get_retval(tr)[1] .- get_retval(new_trace)[1], cmap="Blues", origin="lower", extent=(0, duration, 0, audio_sr/2), aspect="auto")

# %%
plot_gtg(get_retval(tr)[1], t, f, duration, audio_sr/2)

# %%
plot_gtg(get_retval(new_trace)[1], t, f, duration, audio_sr/2)

# %% [markdown]
# ### Split/Merge: split has a problem because it needs to choose so precisely

# %%
constraints = choicemap()

constraints[:n_sources] = 1
constraints[:source => 1 => :n_tones] = 2
mu_erb_1 = 13; mu_amp_1 =0.9;
constraints[:source => 1 => :mu_erb] = mu_erb_1
constraints[:source => 1 => :mu_amp] = mu_amp_1
wait_1 = 0.4; dur_minus_min_1 = 0.03000001; offset_1=wait_1+dur_minus_min_1 + 0.020
constraints[:source => 1 => (:tone, 1) => :wait] = wait_1
constraints[:source => 1 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, offset_1], tstep)
constraints[:source => 1 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 1 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

mu_erb_2 = 20; mu_amp_2 =0.9;
constraints[:source => 1 => :mu_erb] = mu_erb_2
constraints[:source => 1 => :mu_amp] = mu_amp_2 
wait_2 = 0; dur_minus_min_2 = 0.030000001; onset_2 = offset_1+wait_2; offset_2=onset_2+dur_minus_min_2+0.020
constraints[:source => 1 => (:tone, 2) => :wait]= wait_2
constraints[:source => 1 => (:tone, 2) => :dur_minus_min]= dur_minus_min_2
t = get_tone_sample_times([onset_2, offset_2], tstep)
constraints[:source => 1 => (:tone, 2) => :erb]= fill(mu_erb_2, length(t))
constraints[:source => 1 => (:tone, 2) => :amp]= fill(mu_amp_2, length(t));

constraints[:noise] = 0.01

obs_trace, _ = generate(generate_scene, (max_tones, duration, wts, mindur, tstep, audio_sr), constraints)
scene_gram, t, scene_wave = get_retval(obs_trace)
print("Score: ", get_score(obs_trace))
plot_gtg(scene_gram, t, f, duration, audio_sr/2)

# %%
constraints = choicemap()

constraints[:n_sources] = 1
constraints[:source => 1 => :n_tones] = 1
constraints[:source => 1 => :mu_erb] = mu_erb_1
constraints[:source => 1 => :mu_amp] = mu_amp_1
wait_1 = 0.4; dur_minus_min_1 = 0.080
constraints[:source => 1 => (:tone, 1) => :wait] = wait_1
constraints[:source => 1 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, wait_1+dur_minus_min_1 + 0.020], tstep)
constraints[:source => 1 => (:tone, 1) => :erb]= vcat(fill(mu_erb_1, 5),fill(mu_erb_2,6))
constraints[:source => 1 => (:tone, 1) => :amp]= vcat(fill(mu_amp_1, length(t)))
constraints[:noise] = 0.01

constraints[:scene] = scene_gram

init_trace, _ = generate(generate_scene, (max_tones, duration, wts, mindur, tstep, audio_sr), constraints)
plot_gtg(init_trace[:scene], t, f, duration, audio_sr/2) 
plot_sources(init_trace, scene_gram, 1)

# %%
(fwd_choices, fwd_score, fwd_ret) = propose(sm_randomness, (init_trace,1))
(new_trace, bwd_choices, weight) = sm_involution(init_trace, fwd_choices, fwd_ret, (1,))
(bwd_score, _) = assess(sm_randomness, (new_trace,1), bwd_choices)
println("Acceptance probability: ", (weight - fwd_score + bwd_score))
println("Weight: $(weight), Fwd: $(fwd_score), Bwd: $(bwd_score)")
old_score = get_score(init_trace)
new_score = get_score(new_trace)
old_scene, _, _ = get_retval(init_trace)
new_scene, _, _ = get_retval(new_trace)
old_likelihood=logpdf(noisy_matrix,old_scene,scene_gram,init_trace[:noise])
new_likelihood=logpdf(noisy_matrix,new_scene,scene_gram,new_trace[:noise])
println("Old score: $old_score, New score: $new_score")
println("Old likelihood: $old_likelihood, New likelihood: $new_likelihood")
# trace, accepted = mh(trace, switch_randomness, (), switch_involution)
# plot_sources(tr, scene_gram, 1)
plot_sources(new_trace, scene_gram, 1)
println("Forward choices: ", fwd_choices)
println("Backward choices: ", bwd_choices)

# %% [markdown]
# ### Adding or removing a tone

# %%
constraints = choicemap()

constraints[:n_sources] = 1
constraints[:source => 1 => :n_tones] = 1
mu_erb_1 = 13; mu_amp_1 =0.9;
constraints[:source => 1 => :mu_erb] = mu_erb_1
constraints[:source => 1 => :mu_amp] = mu_amp_1
wait_1 = 0.4; dur_minus_min_1 = 0.03000001; offset_1=wait_1+dur_minus_min_1 + 0.020
constraints[:source => 1 => (:tone, 1) => :wait] = wait_1
constraints[:source => 1 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, offset_1], tstep)
constraints[:source => 1 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 1 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

# mu_erb_2 = 20; mu_amp_2 =0.9;
# constraints[:source => 1 => :mu_erb] = mu_erb_2
# constraints[:source => 1 => :mu_amp] = mu_amp_2 
# wait_2 = 0; dur_minus_min_2 = 0.030000001; onset_2 = offset_1+wait_2; offset_2=onset_2+dur_minus_min_2+0.020
# constraints[:source => 1 => (:tone, 2) => :wait]= wait_2
# constraints[:source => 1 => (:tone, 2) => :dur_minus_min]= dur_minus_min_2
# t = get_tone_sample_times([onset_2, offset_2], tstep)
# constraints[:source => 1 => (:tone, 2) => :erb]= fill(mu_erb_2, length(t))
# constraints[:source => 1 => (:tone, 2) => :amp]= fill(mu_amp_2, length(t));

constraints[:noise] = 0.01

obs_trace, _ = generate(generate_scene, (max_tones, duration, wts, mindur, tstep, audio_sr), constraints)
scene_gram, t, scene_wave = get_retval(obs_trace)
print("Score: ", get_score(obs_trace))
plot_gtg(scene_gram, t, f, duration, audio_sr/2)

# %%
constraints = choicemap()

constraints[:n_sources] = 1
constraints[:source => 1 => :n_tones] = 2
mu_erb_1 = 13; mu_amp_1 =0.9;
constraints[:source => 1 => :mu_erb] = mu_erb_1
constraints[:source => 1 => :mu_amp] = mu_amp_1
wait_1 = 0.4; dur_minus_min_1 = 0.03000001; offset_1=wait_1+dur_minus_min_1 + 0.020
constraints[:source => 1 => (:tone, 1) => :wait] = wait_1
constraints[:source => 1 => (:tone, 1) => :dur_minus_min] = dur_minus_min_1
t = get_tone_sample_times([wait_1, offset_1], tstep)
constraints[:source => 1 => (:tone, 1) => :erb]= fill(mu_erb_1, length(t))
constraints[:source => 1 => (:tone, 1) => :amp]= fill(mu_amp_1, length(t))

mu_erb_2 = 20; mu_amp_2 =0.9;
constraints[:source => 1 => :mu_erb] = mu_erb_2
constraints[:source => 1 => :mu_amp] = mu_amp_2 
wait_2 = 0; dur_minus_min_2 = 0.030000001; onset_2 = offset_1+wait_2; offset_2=onset_2+dur_minus_min_2+0.020
constraints[:source => 1 => (:tone, 2) => :wait]= wait_2
constraints[:source => 1 => (:tone, 2) => :dur_minus_min]= dur_minus_min_2
t = get_tone_sample_times([onset_2, offset_2], tstep)
constraints[:source => 1 => (:tone, 2) => :erb]= fill(mu_erb_2, length(t))
constraints[:source => 1 => (:tone, 2) => :amp]= fill(mu_amp_2, length(t));

constraints[:noise] = 0.01

constraints[:scene] = scene_gram

init_trace, _ = generate(generate_scene, (max_tones, duration, wts, mindur, tstep, audio_sr), constraints)
plot_gtg(init_trace[:scene], t, f, duration, audio_sr/2) 
plot_sources(init_trace, scene_gram, 1)

# %%
(fwd_choices, fwd_score, fwd_ret) = propose(n_randomness, (init_trace,1))
(new_trace, bwd_choices, weight) = n_involution(init_trace, fwd_choices, fwd_ret, (1,))
(bwd_score, _) = assess(n_randomness, (new_trace,1), bwd_choices)
println("Acceptance probability: ", (weight - fwd_score + bwd_score))
println("Weight: $(weight), Fwd: $(fwd_score), Bwd: $(bwd_score)")
old_score = get_score(init_trace)
new_score = get_score(new_trace)
old_scene, _, _ = get_retval(init_trace)
new_scene, _, _ = get_retval(new_trace)
old_likelihood=logpdf(noisy_matrix,old_scene,scene_gram,new_trace[:noise])
new_likelihood=logpdf(noisy_matrix,new_scene,scene_gram,new_trace[:noise])
println("Old score: $old_score, New score: $new_score")
println("Old likelihood: $old_likelihood, New likelihood: $new_likelihood")
# trace, accepted = mh(trace, switch_randomness, (), switch_involution)
# plot_sources(tr, scene_gram, 1)
plot_sources(new_trace, scene_gram, 1)
println("Forward choices: ", fwd_choices)
println("Backward choices: ", bwd_choices)

# %%
true && false
